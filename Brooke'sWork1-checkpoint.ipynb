# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

watson_healthcare_path = pd.read_csv (r"C:\Users\User\Desktop\GitHub Respositories\Project 1\Project-1\AttritionData\.ipynb_checkpoints\watson_healthcare_nurses1.csv", delimiter=',')

watson_healthcare_path
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5388\1760848238.py:6: DtypeWarning: Columns (2,3,5,8,11,15,17,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   watson_healthcare_path = pd.read_csv (r"C:\Users\User\Desktop\GitHub Respositories\Project 1\Project-1\AttritionData\.ipynb_checkpoints\watson_healthcare_nurses1.csv", delimiter=',')
#          EmployeeID   Age Attrition     BusinessTravel  DailyRate  Department  \
# 0         1313919.0  41.0        No      Travel_Rarely     1102.0  Cardiology
# 1         1060315.0  37.0       Yes      Travel_Rarely     1373.0   Maternity
# 2         1414939.0  27.0        No      Travel_Rarely      591.0   Maternity
# 3         1633361.0  32.0        No  Travel_Frequently     1005.0   Maternity
# 4         1329390.0  59.0        No      Travel_Rarely     1324.0   Maternity
# ...             ...   ...       ...                ...        ...         ...
# ...

# %%
#define data frame

df = pd.DataFrame(watson_healthcare_path1)
print(df)

watson_healthcare_path1 = df.dropna(how=all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5388\3053569719.py in <module>
#       1 #define data frame
#       2
# ----> 3 df = pd.DataFrame(watson_healthcare_path1)
#       4 print(df)
#       5
#
# NameError: name 'watson_healthcare_path1' is not defined

# %%
df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(df)
# Out:
#          EmployeeID   Age Attrition     BusinessTravel  DailyRate  Department  \
# 0         1313919.0  41.0        No      Travel_Rarely     1102.0  Cardiology
# 1         1060315.0  37.0       Yes      Travel_Rarely     1373.0   Maternity
# 2         1414939.0  27.0        No      Travel_Rarely      591.0   Maternity
# 3         1633361.0  32.0        No  Travel_Frequently     1005.0   Maternity
# 4         1329390.0  59.0        No      Travel_Rarely     1324.0   Maternity
# ...             ...   ...       ...                ...        ...         ...
# 1047716         NaN   NaN       NaN                NaN        NaN         NaN
# 1047717         NaN   NaN       NaN                NaN        NaN         NaN
# 1047718         NaN   NaN       NaN                NaN        NaN         NaN
# 1047719         NaN   NaN       NaN                NaN        NaN         NaN
# 1047720         NaN   NaN       NaN                NaN        NaN         NaN
#
# ...

# %%
#remove duplicates
clean_data=watson_healthcare_path.drop_duplicates
clean_data
# Out:
# <bound method DataFrame.drop_duplicates of          EmployeeID   Age Attrition     BusinessTravel  DailyRate  Department  \
# 0         1313919.0  41.0        No      Travel_Rarely     1102.0  Cardiology
# 1         1060315.0  37.0       Yes      Travel_Rarely     1373.0   Maternity
# 2         1414939.0  27.0        No      Travel_Rarely      591.0   Maternity
# 3         1633361.0  32.0        No  Travel_Frequently     1005.0   Maternity
# 4         1329390.0  59.0        No      Travel_Rarely     1324.0   Maternity
# ...             ...   ...       ...                ...        ...         ...
# 1047716         NaN   NaN       NaN                NaN        NaN         NaN
# 1047717         NaN   NaN       NaN                NaN        NaN         NaN
# 1047718         NaN   NaN       NaN                NaN        NaN         NaN
# 1047719         NaN   NaN       NaN                NaN        NaN         NaN
# ...

# %%
#Remove duplicates
watson_healthcare_path.sort_values("EmployeeID",inplace=True)
watson_healthcare_path.drop_duplicates(subset="EmployeeID", keep=False, inplace=True)
watson_healthcare_path
# Out:
#      EmployeeID   Age Attrition     BusinessTravel  DailyRate  Department  \
# 280   1025177.0  40.0        No  Travel_Frequently      791.0   Maternity
# 50    1026798.0  24.0        No      Travel_Rarely     1353.0  Cardiology
# 499   1028391.0  49.0        No      Travel_Rarely     1495.0   Maternity
# 742   1030882.0  31.0        No      Travel_Rarely      670.0   Maternity
# 796   1031059.0  42.0        No      Travel_Rarely      916.0   Maternity
# ..          ...   ...       ...                ...        ...         ...
# 522   1879823.0  42.0        No      Travel_Rarely     1210.0   Maternity
# 618   1880660.0  37.0        No      Travel_Rarely      589.0  Cardiology
# 560   1883424.0  40.0       Yes      Travel_Rarely     1329.0   Maternity
# 224   1884554.0  34.0        No      Travel_Rarely      258.0  Cardiology
# 258   1886378.0  40.0        No  Travel_Frequently      580.0  Cardiology
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# ...

# %%
# pull/sort the data needed;
#to verify no duplicates, will equal true if there are no duplicates
watson_df = not df["EmployeeID"].is_unique
watson_df = df ["EmployeeID"].duplicated().any()
watson_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5388\608002994.py in <module>
#       1 # pull/sort the data needed;
#       2 #to verify no duplicates, will equal true if there are no duplicates
# ----> 3 watson_df = not df["EmployeeID"].is_unique
#       4 watson_df = df ["EmployeeID"].duplicated().any()
#       5 watson_df
#
# NameError: name 'df' is not defined

# %%
attrition = watson_healthcare_path.groupby(["Attrition"]).count()["EmployeeID"] # whether still working or not
pandas_plot = attrition.plot(kind="bar", color= 'y')
plt.xlabel("Attrition")
plt.ylabel("Number of Nurses")
plt.title ("Attrition vs Number of Nurses")
attrition
# Out:
# Attrition
# No     715
# Yes    107
# Name: EmployeeID, dtype: int64

# %%
# travel_rarely considered full-time, travel_frequently considered part-time or travel
#Travel nurse vs full time (single location)

NurseType = watson_healthcare_path.groupby(["BusinessTravel"]).count()
pandas_plot = NurseType.plot(kind="bar", y="HourlyRate")
plt.xlabel("Travel vs Non Travel Nurses")
plt.ylabel("Hourly Rate")
plt.title ("Nurses Travel Status vs Hourly Rate")
plt.savefig
NurseType
# Out:
#                    EmployeeID  Age  Attrition  DailyRate  Department  \
# BusinessTravel
# Non-Travel                 93   93         93         93          93
# Travel_Frequently         162  162        162        162         162
# Travel_Rarely             567  567        567        567         567
#
#                    DistanceFromHome  Education  EducationField  EmployeeCount  \
# BusinessTravel
# Non-Travel                       93         93              93             93
# Travel_Frequently               162        162             162            162
# Travel_Rarely                   567        567             567            567
#
#                    EnvironmentSatisfaction  ...  RelationshipSatisfaction  \
# BusinessTravel                              ...
# Non-Travel                              93  ...                        93
# Travel_Frequently                      162  ...                       162
# ...

# %%
 #use this as base pay, Travel freq = travel nurses ; travel rarely = full time
monthly_income = watson_healthcare_path.groupby(["DailyRate"]).count()["EmployeeID"] 
pandas_plot = attrition.plot(kind="bar", color= 'y')
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")
plt.title ("Attrition vs Number of Employees")
attrition
# Out:
# Attrition
# No     715
# Yes    107
# Name: EmployeeID, dtype: int64

# %%
attrition_mean = watson_healthcare_path.groupby("Attrition").mean()["MonthlyIncome"]
attrition_mean
attrition_median = watson_healthcare_path.groupby("Attrition").median()["MonthlyIncome"]
attrition_median
attrition_variance = watson_healthcare_path.groupby("Attrition").var()["MonthlyIncome"]
attrition_variance
attrition_stdev = watson_healthcare_path.groupby("Attrition").std()["MonthlyIncome"]
attrition_stdev 

summary_stats = pd.DataFrame ({"Monthly Income Mean": attrition_mean, "Monthly Income Median": attrition_median,  
                              "Monthly Income Standard Deviation": attrition_stdev})
summary_stats
# Out:
#            Monthly Income Mean  Monthly Income Median  \
# Attrition
# No                 5685.593007                 5204.0
# Yes                4556.205607                 3722.0
#
#            Monthly Income Standard Deviation
# Attrition
# No                               2740.081472
# Yes                              2841.466353

# %%
#income vs part time (line graph)
attrition_df = watson_healthcare_path.loc[watson_healthcare_path['MonthlyIncome'],:]
attrition_df

x_axis = watson_healthcare_path["MonthlyIncome"]
nontravel_df=watson_healthcare_path["Attrition"]

fig1,ax1 = plt.subplots(figsize=(13,7))
plt.title("Test")
plt.plot(x_axis, nontravel_df, color="blue")
plt.xlabel("Monthly Income")
plt.ylabel("Attrition")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2880\1830396724.py in <module>
#       1 #income vs part time (line graph)
# ----> 2 attrition_df = watson_healthcare_path.loc[watson_healthcare_path['MonthlyIncome'],:]
#       3 attrition_df
#       4
#       5 x_axis = watson_healthcare_path["MonthlyIncome"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# ...
