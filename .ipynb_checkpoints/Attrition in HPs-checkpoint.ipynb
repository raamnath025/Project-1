# %%
# Creating dependencies
import pandas as pd 
import matplotlib.pyplot as plt
hpDF = pd.read_csv("Resources/Healthcare-Employee-Attrition.csv")

# %%
# Displaying dataframe
hpDF.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   55       Yes      Travel_Rarely        725  Research & Development
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 2          3        Medical              1             787
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         4            80                 1
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 24                      2               3               5
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  2                        1                     4
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
# Displaying columns in dataframe.
hpDF.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Displaying the attrition count using the Counter function
from collections import Counter

print(dict(Counter(hpDF['Attrition'])))
# Out:
# {'Yes': 237, 'No': 1233}

# %%
# Displaying the attrition rate as a pie chart
keys = ['No', 'Yes']
data = [1233, 237]

plt.pie(data, labels = keys, autopct='%.0f%%')
plt.title("Total Attrition Ratio Among Healthcare Professionals")
plt.show()

# %%
# Defining a dictionary based on attrition count.
# Plotting a pie chart on attrition rate based on gender 
def get_pie_chart(hpDF, categorical_column, categorical_value):
        df_category = hpDF[hpDF[categorical_column] == categorical_value].copy()
        attrition_dict = dict(Counter(df_category['Attrition']))

        keys = list(attrition_dict.keys())
        data = list(attrition_dict.values())

        plt.pie(data, labels = keys, autopct='%.0f%%')
        plt.title(f"Attrition for {categorical_value}")
        plt.show()

# %%
# Displaying the pie chart
get_pie_chart(hpDF, 'Gender', 'Male')
get_pie_chart(hpDF, 'Gender', 'Female')

# %%
# Utilizing seaborn dependency to display visually robust informative statistical graphics

import seaborn as sb

# Defining the variables to create a bivariate histoplot to show the 
# distributions of attrition rate  based on monthly income
def get_attrition_box_plot(hpDF, numerical_column):
    sb.boxplot(x= hpDF['Attrition'], y = df_in[numerical_column])
    plt.show()

# %%
# Displaying the histogram
sb.histplot(data=hpDF, x="MonthlyIncome", hue="Attrition", kde=True)

sb.set()

# %%
# Created a new csv file keeping only the datapoints that are positive for attrition and based on the columns of interest
# Created dataframe based on new csv file
hp_newDF = "Resources/HPmodified_AttritionOnly.csv"

# %%
# read new csv
hp_newDF = pd.read_csv(hp_newDF)
hp_newDF.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   26         Non-Travel                   Sales                29
# 1   31  Travel_Frequently  Research & Development                29
# 2   33  Travel_Frequently  Research & Development                29
# 3   38      Travel_Rarely  Research & Development                29
# 4   47         Non-Travel  Research & Development                29
#
#   EducationField  Gender  JobLevel                    JobRole  \
# 0        Medical    Male         2            Sales Executive
# 1        Medical    Male         1      Laboratory Technician
# 2        Medical  Female         2         Research Scientist
# 3        Medical    Male         2  Healthcare Representative
# 4  Life Sciences    Male         3                    Manager
#
#    JobSatisfaction  MonthlyIncome OverTime  YearsAtCompany
# 0                1           4969       No               2
# 1                2           3479       No               5
# 2                3           4508       No              13
# 3                1           6673      Yes               1
# 4                2          11849      Yes              10

# %%
# Displaying the columns in the new dataframe
hp_newDF.columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'Gender', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MonthlyIncome', 'OverTime', 'YearsAtCompany'],
#       dtype='object')

# %%
# statistical description of data
hp_newDF.describe().T
# Out:
#                   count         mean          std     min      25%     50%  \
# Age               152.0    34.052632     9.759213    18.0    28.00    32.0
# DistanceFromHome  152.0    10.506579     8.669805     1.0     2.75     9.0
# JobLevel          152.0     1.605263     0.914619     1.0     1.00     1.0
# JobSatisfaction   152.0     2.434211     1.119786     1.0     1.00     3.0
# MonthlyIncome     152.0  4653.855263  3479.143389  1009.0  2379.25  3368.0
# YearsAtCompany    152.0     5.131579     5.857790     0.0     1.00     3.0
#
#                       75%      max
# Age                 39.25     58.0
# DistanceFromHome    16.25     29.0
# JobLevel             2.00      5.0
# JobSatisfaction      3.00      4.0
# MonthlyIncome     5533.25  19859.0
# YearsAtCompany       7.25     40.0

# %%
# checking dataset info
hp_newDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               152 non-null    int64
#  1   BusinessTravel    152 non-null    object
#  2   Department        152 non-null    object
#  3   DistanceFromHome  152 non-null    int64
#  4   EducationField    152 non-null    object
#  5   Gender            152 non-null    object
#  6   JobLevel          152 non-null    int64
#  7   JobRole           152 non-null    object
#  8   JobSatisfaction   152 non-null    int64
#  9   MonthlyIncome     152 non-null    int64
#  10  OverTime          152 non-null    object
#  11  YearsAtCompany    152 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 14.4+ KB

# %%
# Defining a variable and creating conditions to seperate the categorical and continuous variables
def cat_con_split(hp_newDF):
    cat, con = [], []
    for i in hp_newDF.columns:
        if hp_newDF[i].dtype=='object':
            cat.append(i)
        else:
            con.append(i)
    return cat, con

# %%
cat,con = cat_con_split(hp_newDF)

# %%
# Displaying the categorical variables
cat
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'OverTime']

# %%
# Displaying the continuous variables
con
# Out:
# ['Age',
#  'DistanceFromHome',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'YearsAtCompany']

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Analysis of Distribution in Each Variable

# %%
# analysis of continuous variables based on columns of interest
plt.figure(figsize=(30,30))
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
x = 1

for i in con:
    plt.subplot(9,3,x)
    x = x+1
    sb.histplot(data = hp_newDF, x = i, kde=True)
plt.show()

# %%
# analysis of categorical variables based on columns of interest
plt.figure(figsize=(30,30))
x = 1
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
for i in cat:
    plt.subplot(3,3,x)
    x = x+1
    hp_newDF[i].value_counts().plot(kind='bar')
    plt.title(i)
plt.show()

# %% [markdown]
# ## Human Resources

# %%
# Creating a dataframe based on employees in the Human Resources department 
HR_df = hp_newDF[(hp_newDF["Department"] == "Human Resources")]
HR_df
# Out:
#      Age     BusinessTravel       Department  DistanceFromHome EducationField  \
# 31    26      Travel_Rarely  Human Resources                20        Medical
# 36    26  Travel_Frequently  Human Resources                17  Life Sciences
# 140   44      Travel_Rarely  Human Resources                 1        Medical
#
#      Gender  JobLevel          JobRole  JobSatisfaction  MonthlyIncome  \
# 31   Female         1  Human Resources                2           2148
# 36   Female         1  Human Resources                3           2741
# 140    Male         3  Human Resources                1          10482
#
#     OverTime  YearsAtCompany
# 31       Yes               5
# 36       Yes               7
# 140       No              20

# %%
# analysis of continuous variables in Human Resources
plt.figure(figsize=(30,30))
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
x = 1

for i in con:
    plt.subplot(9,3,x)
    x = x+1
    sb.histplot(data = HR_df, x = i, kde=True)
plt.show()

# %%
# analysis of categorical variables in Human Resources
plt.figure(figsize=(30,30))
x = 1
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
for i in cat:
    plt.subplot(3,3,x)
    x = x+1
    HR_df[i].value_counts().plot(kind='bar')
    plt.title(i)
plt.show()

# %% [markdown]
# ## Research & Development

# %%
# Creating a dataframe based on employees in the Research & Development department
RnD_df = hp_newDF[(hp_newDF["Department"] == "Research & Development")]
RnD_df
# Out:
#      Age     BusinessTravel              Department  DistanceFromHome  \
# 1     31  Travel_Frequently  Research & Development                29
# 2     33  Travel_Frequently  Research & Development                29
# 3     38      Travel_Rarely  Research & Development                29
# 4     47         Non-Travel  Research & Development                29
# 5     49  Travel_Frequently  Research & Development                28
# ..   ...                ...                     ...               ...
# 144   29      Travel_Rarely  Research & Development                 1
# 145   29      Travel_Rarely  Research & Development                 1
# 148   32      Travel_Rarely  Research & Development                 1
# 150   44  Travel_Frequently  Research & Development                 1
# 151   48      Travel_Rarely  Research & Development                 1
#
#     EducationField  Gender  JobLevel                    JobRole  \
# 1          Medical    Male         1      Laboratory Technician
# 2          Medical  Female         2         Research Scientist
# 3          Medical    Male         2  Healthcare Representative
# 4    Life Sciences    Male         3                    Manager
# 5    Life Sciences    Male         2      Laboratory Technician
# ..             ...     ...       ...                        ...
# 144  Life Sciences  Female         1      Laboratory Technician
# 145        Medical    Male         1         Research Scientist
# 148  Life Sciences    Male         1      Laboratory Technician
# 150        Medical    Male         1         Research Scientist
# 151  Life Sciences    Male         3      Laboratory Technician
#
#      JobSatisfaction  MonthlyIncome OverTime  YearsAtCompany
# 1                  2           3479       No               5
# 2                  3           4508       No              13
# 3                  1           6673      Yes               1
# 4                  2          11849      Yes              10
# 5                  1           4284       No               4
# ..               ...            ...      ...             ...
# 144                1           2319      Yes               1
# 145                4           4787      Yes               2
# 148                3           3730      Yes               3
# 150                2           2342      Yes               5
# 151                3           5381      Yes               1
#
# [106 rows x 12 columns]

# %%
# analysis of continuous variables in Research & Development
plt.figure(figsize=(30,30))
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
x = 1

for i in con:
    plt.subplot(9,3,x)
    x = x+1
    sb.histplot(data = RnD_df, x = i, kde=True)
plt.show()

# %%
# analysis of categorical variables in Research & Development
plt.figure(figsize=(30,30))
x = 1
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
for i in cat:
    plt.subplot(3,3,x)
    x = x+1
    RnD_df[i].value_counts().plot(kind='bar')
    plt.title(i)
plt.show()

# %% [markdown]
# ## Sales

# %%
# Creating a dataframe based on employees in the Sales department
Sales_df = hp_newDF[(hp_newDF["Department"] == "Sales")]
Sales_df.head()
# Out:
#     Age     BusinessTravel Department  DistanceFromHome EducationField  \
# 0    26         Non-Travel      Sales                29        Medical
# 6    35      Travel_Rarely      Sales                27  Life Sciences
# 7    47  Travel_Frequently      Sales                27  Life Sciences
# 8    45  Travel_Frequently      Sales                26  Life Sciences
# 14   25  Travel_Frequently      Sales                24  Life Sciences
#
#     Gender  JobLevel               JobRole  JobSatisfaction  MonthlyIncome  \
# 0     Male         2       Sales Executive                1           4969
# 6     Male         2       Sales Executive                4           5813
# 7   Female         2       Sales Executive                3           6397
# 8   Female         2       Sales Executive                1           4286
# 14    Male         1  Sales Representative                4           1118
#
#    OverTime  YearsAtCompany
# 0        No               2
# 6       Yes              10
# 7       Yes               5
# 8        No               1
# 14      Yes               1

# %%
# analysis of continuous variables in Sales
plt.figure(figsize=(30,30))
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
x = 1

for i in con:
    plt.subplot(9,3,x)
    x = x+1
    sb.histplot(data = Sales_df, x = i, kde=True)
plt.show()

# %%
# analysis of categorical variables in Sales
plt.figure(figsize=(30,30))
x = 1
plt.subplots_adjust(top = 0.99, bottom=0.01, hspace=0.5, wspace=0.1)
for i in cat:
    plt.subplot(3,3,x)
    x = x+1
    Sales_df[i].value_counts().plot(kind='bar')
    plt.title(i)
plt.show()
